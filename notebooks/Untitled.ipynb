# %%
import os

print(os.listdir("resume_classifier"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os
#       2
# ----> 3 print(os.listdir("resume_classifier"))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'resume_classifier'
